# %%
import os
import argparse
import numpy as np
from datasets.dataset_generic import Generic_WSI_Classification_Dataset, Generic_MIL_Dataset, save_splits

# %%
label_frac = 1.0
seed = 1
k = 5
val_frac = 0.15
test_frac = 0.15

# task_1_fungal_vs_nonfungal
n_classes=2
# fungal_vs_nonfungal.csv
# tumor_vs_normal_dummy_clean.csv
dataset = Generic_WSI_Classification_Dataset(csv_path = 'dataset_csv/fungal_vs_nonfungal.csv',
                        shuffle = False,
                        seed = seed,
                        print_info = True,
#                         label_dict = {'normal_tissue':0, 'tumor_tissue':1},
                        label_dict = {'nonfungal':0, 'fungal':1},
                        patient_strat=True,
                        ignore=[])

num_slides_cls = np.array([len(cls_ids) for cls_ids in dataset.patient_cls_ids])
val_num = np.round(num_slides_cls * val_frac).astype(int)
test_num = np.round(num_slides_cls * test_frac).astype(int)
# Out:
#       case_id  slide_id label
# 0      case_0   F005a02     1
# 1      case_1   F006a01     1
# 2      case_2   F006a02     1
# 3      case_3   F006a03     1
# 4      case_4   F006a04     1
# ..        ...       ...   ...
# 317  case_317  N007a004     0
# 318  case_318  N009a001     0
# 319  case_319  N009a002     0
# 320  case_320  N011a001     0
# 321  case_321  N017a001     0
#
# [322 rows x 3 columns]
# label column: label
# label dictionary: {'nonfungal': 0, 'fungal': 1}
# number of classes: 2
# slide-level counts:
#  0    182
# 1    140
# Name: label, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 182
# Slide-LVL; Number of samples registered in class 0: 182
# Patient-LVL; Number of samples registered in class 1: 140
# Slide-LVL; Number of samples registered in class 1: 140

# %%
if __name__ == '__main__':
    if label_frac > 0:
        label_fracs = [label_frac]
    else:
        label_fracs = [0.1, 0.25, 0.5, 0.75, 1.0]

    for lf in label_fracs:
        split_dir = 'splits/fungal_vs_nonfungal' + '_{}'.format(int(lf * 100))
#         split_dir = 'splits/tumor_vs_normal_dummy_clean/' + '_{}'.format(int(lf * 100))
        os.makedirs(split_dir, exist_ok=True)
        dataset.create_splits(k = k, val_num = val_num, test_num = test_num, label_frac=lf)
        for i in range(k):
            dataset.set_splits()
            descriptor_df = dataset.test_split_gen(return_descriptor=True)
            splits = dataset.return_splits(from_id=True)
            
            save_splits(splits, ['train', 'val', 'test'], os.path.join(split_dir, 'splits_{}.csv'.format(i)))
            save_splits(splits, ['train', 'val', 'test'], os.path.join(split_dir, 'splits_{}_bool.csv'.format(i)), boolean_style=True)
            descriptor_df.to_csv(os.path.join(split_dir, 'splits_{}_descriptor.csv'.format(i)))
# Out:
# number of training samples: 226
# number of samples in cls 0: 128
# number of samples in cls 1: 98
#
# number of val samples: 48
# number of samples in cls 0: 27
# number of samples in cls 1: 21
#
# number of test samples: 48
# number of samples in cls 0: 27
# number of samples in cls 1: 21
# (<datasets.dataset_generic.Generic_Split object at 0x7f34403cc410>, <datasets.dataset_generic.Generic_Split object at 0x7f343c5ccc50>, <datasets.dataset_generic.Generic_Split object at 0x7f342c082d10>)
#       case_id  slide_id label
# 0    case_140  N001a001     0
# 1    case_143  N003a002     0
# 2    case_145  N004a001     0
# 3    case_146  N004a002     0
# 4    case_148  N004a004     0
# ..        ...       ...   ...
# 221   case_93   F030a05     1
# 222   case_94   F030a06     1
# 223   case_96   F030a08     1
# 224   case_97   F030a09     1
# 225   case_98   F030a10     1
#
# [226 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f34403cc410>, <datasets.dataset_generic.Generic_Split object at 0x7f343c5ccc50>, <datasets.dataset_generic.Generic_Split object at 0x7f342c082d10>)
#       case_id  slide_id label
# 0    case_140  N001a001     0
# 1    case_143  N003a002     0
# 2    case_145  N004a001     0
# 3    case_146  N004a002     0
# 4    case_148  N004a004     0
# ..        ...       ...   ...
# 221   case_93   F030a05     1
# 222   case_94   F030a06     1
# 223   case_96   F030a08     1
# 224   case_97   F030a09     1
# 225   case_98   F030a10     1
#
# [226 rows x 3 columns]
#
#
# number of training samples: 226
# number of samples in cls 0: 128
# number of samples in cls 1: 98
#
# number of val samples: 48
# number of samples in cls 0: 27
# number of samples in cls 1: 21
#
# number of test samples: 48
# number of samples in cls 0: 27
# number of samples in cls 1: 21
# (<datasets.dataset_generic.Generic_Split object at 0x7f3333e50d10>, <datasets.dataset_generic.Generic_Split object at 0x7f343e6b8550>, <datasets.dataset_generic.Generic_Split object at 0x7f3333e814d0>)
#       case_id  slide_id label
# 0    case_140  N001a001     0
# 1    case_141  N001a002     0
# 2    case_142  N003a001     0
# 3    case_143  N003a002     0
# 4    case_144  N003a003     0
# ..        ...       ...   ...
# 221   case_93   F030a05     1
# 222   case_94   F030a06     1
# 223   case_95   F030a07     1
# 224   case_96   F030a08     1
# 225   case_99   F030a11     1
#
# [226 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f3333e50d10>, <datasets.dataset_generic.Generic_Split object at 0x7f343e6b8550>, <datasets.dataset_generic.Generic_Split object at 0x7f3333e814d0>)
#       case_id  slide_id label
# 0    case_140  N001a001     0
# 1    case_141  N001a002     0
# 2    case_142  N003a001     0
# 3    case_143  N003a002     0
# 4    case_144  N003a003     0
# ..        ...       ...   ...
# 221   case_93   F030a05     1
# 222   case_94   F030a06     1
# 223   case_95   F030a07     1
# 224   case_96   F030a08     1
# 225   case_99   F030a11     1
#
# [226 rows x 3 columns]
#
#
# number of training samples: 226
# number of samples in cls 0: 128
# number of samples in cls 1: 98
#
# number of val samples: 48
# number of samples in cls 0: 27
# number of samples in cls 1: 21
#
# number of test samples: 48
# number of samples in cls 0: 27
# number of samples in cls 1: 21
# (<datasets.dataset_generic.Generic_Split object at 0x7f34403cc410>, <datasets.dataset_generic.Generic_Split object at 0x7f343c5c7590>, <datasets.dataset_generic.Generic_Split object at 0x7f343c5cc810>)
#       case_id  slide_id label
# 0    case_140  N001a001     0
# 1    case_141  N001a002     0
# 2    case_143  N003a002     0
# 3    case_146  N004a002     0
# 4    case_147  N004a003     0
# ..        ...       ...   ...
# 221   case_92   F030a04     1
# 222   case_94   F030a06     1
# 223   case_95   F030a07     1
# 224   case_96   F030a08     1
# 225   case_99   F030a11     1
#
# [226 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f34403cc410>, <datasets.dataset_generic.Generic_Split object at 0x7f343c5c7590>, <datasets.dataset_generic.Generic_Split object at 0x7f343c5cc810>)
#       case_id  slide_id label
# 0    case_140  N001a001     0
# 1    case_141  N001a002     0
# 2    case_143  N003a002     0
# 3    case_146  N004a002     0
# 4    case_147  N004a003     0
# ..        ...       ...   ...
# 221   case_92   F030a04     1
# 222   case_94   F030a06     1
# 223   case_95   F030a07     1
# 224   case_96   F030a08     1
# 225   case_99   F030a11     1
#
# [226 rows x 3 columns]
#
#
# number of training samples: 226
# number of samples in cls 0: 128
# number of samples in cls 1: 98
#
# number of val samples: 48
# number of samples in cls 0: 27
# number of samples in cls 1: 21
#
# number of test samples: 48
# number of samples in cls 0: 27
# number of samples in cls 1: 21
# (<datasets.dataset_generic.Generic_Split object at 0x7f3333ec4f50>, <datasets.dataset_generic.Generic_Split object at 0x7f343c5c7810>, <datasets.dataset_generic.Generic_Split object at 0x7f3333e67d10>)
#       case_id  slide_id label
# 0    case_140  N001a001     0
# 1    case_141  N001a002     0
# 2    case_143  N003a002     0
# 3    case_144  N003a003     0
# 4    case_145  N004a001     0
# ..        ...       ...   ...
# 221   case_93   F030a05     1
# 222   case_94   F030a06     1
# 223   case_97   F030a09     1
# 224   case_98   F030a10     1
# 225   case_99   F030a11     1
#
# [226 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f3333ec4f50>, <datasets.dataset_generic.Generic_Split object at 0x7f343c5c7810>, <datasets.dataset_generic.Generic_Split object at 0x7f3333e67d10>)
#       case_id  slide_id label
# 0    case_140  N001a001     0
# 1    case_141  N001a002     0
# 2    case_143  N003a002     0
# 3    case_144  N003a003     0
# 4    case_145  N004a001     0
# ..        ...       ...   ...
# 221   case_93   F030a05     1
# 222   case_94   F030a06     1
# 223   case_97   F030a09     1
# 224   case_98   F030a10     1
# 225   case_99   F030a11     1
#
# [226 rows x 3 columns]
#
#
# number of training samples: 226
# number of samples in cls 0: 128
# number of samples in cls 1: 98
#
# number of val samples: 48
# number of samples in cls 0: 27
# number of samples in cls 1: 21
#
# number of test samples: 48
# number of samples in cls 0: 27
# number of samples in cls 1: 21
# (<datasets.dataset_generic.Generic_Split object at 0x7f333eed3950>, <datasets.dataset_generic.Generic_Split object at 0x7f343c5cc810>, <datasets.dataset_generic.Generic_Split object at 0x7f3333e673d0>)
#       case_id  slide_id label
# 0    case_140  N001a001     0
# 1    case_141  N001a002     0
# 2    case_142  N003a001     0
# 3    case_143  N003a002     0
# 4    case_146  N004a002     0
# ..        ...       ...   ...
# 221   case_94   F030a06     1
# 222   case_95   F030a07     1
# 223   case_96   F030a08     1
# 224   case_97   F030a09     1
# 225   case_98   F030a10     1
#
# [226 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f333eed3950>, <datasets.dataset_generic.Generic_Split object at 0x7f343c5cc810>, <datasets.dataset_generic.Generic_Split object at 0x7f3333e673d0>)
#       case_id  slide_id label
# 0    case_140  N001a001     0
# 1    case_141  N001a002     0
# 2    case_142  N003a001     0
# 3    case_143  N003a002     0
# 4    case_146  N004a002     0
# ..        ...       ...   ...
# 221   case_94   F030a06     1
# 222   case_95   F030a07     1
# 223   case_96   F030a08     1
# 224   case_97   F030a09     1
# 225   case_98   F030a10     1
#
# [226 rows x 3 columns]
