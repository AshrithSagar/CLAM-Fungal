# %%
import os
import argparse
import numpy as np
from datasets.dataset_generic import Generic_WSI_Classification_Dataset, Generic_MIL_Dataset, save_splits

# %%
label_frac = 1.0
seed = 1
k = 4
val_frac = 0.1
test_frac = 0.1

# task_1_fungal_vs_nonfungal
n_classes=2
# fungal_vs_nonfungal.csv
# tumor_vs_normal_dummy_clean.csv
dataset = Generic_WSI_Classification_Dataset(csv_path = 'dataset_csv/fungal_vs_nonfungal.csv',
                        shuffle = False,
                        seed = seed,
                        print_info = True,
#                         label_dict = {'normal_tissue':0, 'tumor_tissue':1},
                        label_dict = {'nonfungal':0, 'fungal':1},
                        patient_strat=True,
                        ignore=[])

num_slides_cls = np.array([len(cls_ids) for cls_ids in dataset.patient_cls_ids])
val_num = np.round(num_slides_cls * val_frac).astype(int)
test_num = np.round(num_slides_cls * test_frac).astype(int)
# Out:
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2      case_2  F006a02     1
# 3      case_3  F006a03     1
# 4      case_4  F006a04     1
# ..        ...      ...   ...
# 135  case_135  F034a07     1
# 136  case_136  F034a08     1
# 137  case_137  F034a09     1
# 138  case_138  F034a10     1
# 139  case_139  F034a11     1
#
# [140 rows x 3 columns]
# label column: label
# label dictionary: {'nonfungal': 0, 'fungal': 1}
# number of classes: 2
# slide-level counts:
#  1    140
# Name: label, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 0
# Slide-LVL; Number of samples registered in class 0: 0
# Patient-LVL; Number of samples registered in class 1: 140
# Slide-LVL; Number of samples registered in class 1: 140

# %%
if __name__ == '__main__':
    if label_frac > 0:
        label_fracs = [label_frac]
    else:
        label_fracs = [0.1, 0.25, 0.5, 0.75, 1.0]

    for lf in label_fracs:
        split_dir = 'splits/fungal_vs_nonfungal' + '_{}'.format(int(lf * 100))
#         split_dir = 'splits/tumor_vs_normal_dummy_clean/' + '_{}'.format(int(lf * 100))
        os.makedirs(split_dir, exist_ok=True)
        dataset.create_splits(k = k, val_num = val_num, test_num = test_num, label_frac=lf)
        for i in range(k):
            dataset.set_splits()
            descriptor_df = dataset.test_split_gen(return_descriptor=True)
            splits = dataset.return_splits(from_id=True)
            
            save_splits(splits, ['train', 'val', 'test'], os.path.join(split_dir, 'splits_{}.csv'.format(i)))
            save_splits(splits, ['train', 'val', 'test'], os.path.join(split_dir, 'splits_{}_bool.csv'.format(i)), boolean_style=True)
            descriptor_df.to_csv(os.path.join(split_dir, 'splits_{}_descriptor.csv'.format(i)))
# Out:
# number of training samples: 112
# number of samples in cls 1: 112
#
# number of val samples: 14
# number of samples in cls 1: 14
#
# number of test samples: 14
# number of samples in cls 1: 14
# (<datasets.dataset_generic.Generic_Split object at 0x7f79d0fefb10>, <datasets.dataset_generic.Generic_Split object at 0x7f79d0ff92d0>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0b29d0>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1     case_10  F006a10     1
# 2    case_100  F030a12     1
# 3    case_101  F030a13     1
# 4    case_103  F030a15     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_98  F030a10     1
# 111   case_99  F030a11     1
#
# [112 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f79d0fefb10>, <datasets.dataset_generic.Generic_Split object at 0x7f79d0ff92d0>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0b29d0>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1     case_10  F006a10     1
# 2    case_100  F030a12     1
# 3    case_101  F030a13     1
# 4    case_103  F030a15     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_98  F030a10     1
# 111   case_99  F030a11     1
#
# [112 rows x 3 columns]
#
#
# number of training samples: 112
# number of samples in cls 1: 112
#
# number of val samples: 14
# number of samples in cls 1: 14
#
# number of test samples: 14
# number of samples in cls 1: 14
# (<datasets.dataset_generic.Generic_Split object at 0x7f78d6eba650>, <datasets.dataset_generic.Generic_Split object at 0x7f79d98aaa10>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057d50>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1     case_10  F006a10     1
# 2    case_100  F030a12     1
# 3    case_101  F030a13     1
# 4    case_102  F030a14     1
# ..        ...      ...   ...
# 107   case_92  F030a04     1
# 108   case_94  F030a06     1
# 109   case_97  F030a09     1
# 110   case_98  F030a10     1
# 111   case_99  F030a11     1
#
# [112 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f78d6eba650>, <datasets.dataset_generic.Generic_Split object at 0x7f79d98aaa10>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057d50>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1     case_10  F006a10     1
# 2    case_100  F030a12     1
# 3    case_101  F030a13     1
# 4    case_102  F030a14     1
# ..        ...      ...   ...
# 107   case_92  F030a04     1
# 108   case_94  F030a06     1
# 109   case_97  F030a09     1
# 110   case_98  F030a10     1
# 111   case_99  F030a11     1
#
# [112 rows x 3 columns]
#
#
# number of training samples: 112
# number of samples in cls 1: 112
#
# number of val samples: 14
# number of samples in cls 1: 14
#
# number of test samples: 14
# number of samples in cls 1: 14
# (<datasets.dataset_generic.Generic_Split object at 0x7f78df866790>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0b2ad0>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057f50>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2    case_100  F030a12     1
# 3    case_101  F030a13     1
# 4    case_102  F030a14     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_97  F030a09     1
# 111   case_98  F030a10     1
#
# [112 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f78df866790>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0b2ad0>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057f50>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2    case_100  F030a12     1
# 3    case_101  F030a13     1
# 4    case_102  F030a14     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_97  F030a09     1
# 111   case_98  F030a10     1
#
# [112 rows x 3 columns]
#
#
# number of training samples: 112
# number of samples in cls 1: 112
#
# number of val samples: 14
# number of samples in cls 1: 14
#
# number of test samples: 14
# number of samples in cls 1: 14
# (<datasets.dataset_generic.Generic_Split object at 0x7f79d0ff9790>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0b2f90>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057b90>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2     case_10  F006a10     1
# 3    case_100  F030a12     1
# 4    case_101  F030a13     1
# ..        ...      ...   ...
# 107   case_93  F030a05     1
# 108   case_95  F030a07     1
# 109   case_97  F030a09     1
# 110   case_98  F030a10     1
# 111   case_99  F030a11     1
#
# [112 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f79d0ff9790>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0b2f90>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057b90>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2     case_10  F006a10     1
# 3    case_100  F030a12     1
# 4    case_101  F030a13     1
# ..        ...      ...   ...
# 107   case_93  F030a05     1
# 108   case_95  F030a07     1
# 109   case_97  F030a09     1
# 110   case_98  F030a10     1
# 111   case_99  F030a11     1
#
# [112 rows x 3 columns]
#
#
# number of training samples: 112
# number of samples in cls 1: 112
#
# number of val samples: 14
# number of samples in cls 1: 14
#
# number of test samples: 14
# number of samples in cls 1: 14
# (<datasets.dataset_generic.Generic_Split object at 0x7f78df866790>, <datasets.dataset_generic.Generic_Split object at 0x7f79d0ff9e10>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf074090>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1     case_10  F006a10     1
# 2    case_100  F030a12     1
# 3    case_101  F030a13     1
# 4    case_105  F030a18     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_97  F030a09     1
# 111   case_99  F030a11     1
#
# [112 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f78df866790>, <datasets.dataset_generic.Generic_Split object at 0x7f79d0ff9e10>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf074090>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1     case_10  F006a10     1
# 2    case_100  F030a12     1
# 3    case_101  F030a13     1
# 4    case_105  F030a18     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_97  F030a09     1
# 111   case_99  F030a11     1
#
# [112 rows x 3 columns]
#
#
# number of training samples: 112
# number of samples in cls 1: 112
#
# number of val samples: 14
# number of samples in cls 1: 14
#
# number of test samples: 14
# number of samples in cls 1: 14
# (<datasets.dataset_generic.Generic_Split object at 0x7f79d0fefb10>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0745d0>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf074a50>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2    case_100  F030a12     1
# 3    case_101  F030a13     1
# 4    case_102  F030a14     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_97  F030a09     1
# 111   case_98  F030a10     1
#
# [112 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f79d0fefb10>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0745d0>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf074a50>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2    case_100  F030a12     1
# 3    case_101  F030a13     1
# 4    case_102  F030a14     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_97  F030a09     1
# 111   case_98  F030a10     1
#
# [112 rows x 3 columns]
#
#
# number of training samples: 112
# number of samples in cls 1: 112
#
# number of val samples: 14
# number of samples in cls 1: 14
#
# number of test samples: 14
# number of samples in cls 1: 14
# (<datasets.dataset_generic.Generic_Split object at 0x7f79d0ff9790>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057990>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057d50>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2     case_10  F006a10     1
# 3    case_100  F030a12     1
# 4    case_102  F030a14     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_97  F030a09     1
# 111   case_98  F030a10     1
#
# [112 rows x 3 columns]
# (<datasets.dataset_generic.Generic_Split object at 0x7f79d0ff9790>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057990>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057d50>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2     case_10  F006a10     1
# 3    case_100  F030a12     1
# 4    case_102  F030a14     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_97  F030a09     1
# 111   case_98  F030a10     1
#
# [112 rows x 3 columns]
#
#
# number of training samples: 112
# number of samples in cls 1: 112
#
# number of val samples: 14
# number of samples in cls 1: 14
#
# number of test samples: 14
# number of samples in cls 1: 14
# (<datasets.dataset_generic.Generic_Split object at 0x7f78cf0ab490>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057e10>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf074910>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2     case_10  F006a10     1
# 3    case_100  F030a12     1
# 4    case_101  F030a13     1
# ..        ...      ...   ...
# 107   case_92  F030a04     1
# 108   case_93  F030a05     1
# 109   case_95  F030a07     1
# 110   case_96  F030a08     1
# 111   case_98  F030a10     1
#
# [112 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f78cf0ab490>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf057e10>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf074910>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2     case_10  F006a10     1
# 3    case_100  F030a12     1
# 4    case_101  F030a13     1
# ..        ...      ...   ...
# 107   case_92  F030a04     1
# 108   case_93  F030a05     1
# 109   case_95  F030a07     1
# 110   case_96  F030a08     1
# 111   case_98  F030a10     1
#
# [112 rows x 3 columns]
#
#
# number of training samples: 112
# number of samples in cls 1: 112
#
# number of val samples: 14
# number of samples in cls 1: 14
#
# number of test samples: 14
# number of samples in cls 1: 14
# (<datasets.dataset_generic.Generic_Split object at 0x7f79d0fefb10>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0573d0>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0b29d0>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1    case_101  F030a13     1
# 2    case_102  F030a14     1
# 3    case_103  F030a15     1
# 4    case_104  F030a17     1
# ..        ...      ...   ...
# 107   case_95  F030a07     1
# 108   case_96  F030a08     1
# 109   case_97  F030a09     1
# 110   case_98  F030a10     1
# 111   case_99  F030a11     1
#
# [112 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f79d0fefb10>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0573d0>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf0b29d0>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1    case_101  F030a13     1
# 2    case_102  F030a14     1
# 3    case_103  F030a15     1
# 4    case_104  F030a17     1
# ..        ...      ...   ...
# 107   case_95  F030a07     1
# 108   case_96  F030a08     1
# 109   case_97  F030a09     1
# 110   case_98  F030a10     1
# 111   case_99  F030a11     1
#
# [112 rows x 3 columns]
#
#
# number of training samples: 112
# number of samples in cls 1: 112
#
# number of val samples: 14
# number of samples in cls 1: 14
#
# number of test samples: 14
# number of samples in cls 1: 14
# (<datasets.dataset_generic.Generic_Split object at 0x7f78cf0ab490>, <datasets.dataset_generic.Generic_Split object at 0x7f79d0ff9ad0>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf074ad0>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2     case_10  F006a10     1
# 3    case_100  F030a12     1
# 4    case_101  F030a13     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_97  F030a09     1
# 111   case_98  F030a10     1
#
# [112 rows x 3 columns]
#
# (<datasets.dataset_generic.Generic_Split object at 0x7f78cf0ab490>, <datasets.dataset_generic.Generic_Split object at 0x7f79d0ff9ad0>, <datasets.dataset_generic.Generic_Split object at 0x7f78cf074ad0>)
#       case_id slide_id label
# 0      case_0  F005a02     1
# 1      case_1  F006a01     1
# 2     case_10  F006a10     1
# 3    case_100  F030a12     1
# 4    case_101  F030a13     1
# ..        ...      ...   ...
# 107   case_94  F030a06     1
# 108   case_95  F030a07     1
# 109   case_96  F030a08     1
# 110   case_97  F030a09     1
# 111   case_98  F030a10     1
#
# [112 rows x 3 columns]
